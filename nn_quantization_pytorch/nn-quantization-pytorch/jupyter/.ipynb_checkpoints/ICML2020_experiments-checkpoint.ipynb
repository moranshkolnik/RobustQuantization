# %%
import os
import ipyvolume as ipv
from matplotlib import cm
from colorama import Fore
from scipy.interpolate import interp2d
import ipywidgets as widgets
from tqdm import tqdm
# %matplotlib inline
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import pickle
from pylab import rcParams

# %%
# def plot_p(ax, p, c='r'):
#     ax.scatter([p[0]], [p[1]], color=c, s=50);

def create_1D_plot(files_list, xmin, ymin, xmax=None, ymax=None, figname=None, min_value=None, max_value=None, array_name='Z_top1'):
    
#     clrs=['r','g','b','c','m','y','k']
    
    fig, ax = plt.subplots()
    for idx, data_path in enumerate(files_list):
        
        pkl = pickle.load(open(data_path[1], 'rb'))
        X = pkl['X']
        Z = pkl[array_name]
        print(Z)

        best_point = pkl['best_point'] if 'best_point' in pkl.keys() else None

        if max_value: 
            Z[Z>max_value] = max_value

        if min_value: 
            Z[Z<min_value] = min_value

        if idx == 1:
            ax.plot(X,Z, marker="o",c='r', label=str(data_path[0]),linewidth=3)
        else:
            ax.plot(X,Z, marker="o", label=str(data_path[0]),linewidth=3)

    plt.legend(loc='lower right', fontsize=20)

    # Add title and axis names
    # plt.title('My title')
    plt.xlabel(r'$\Delta$/$\Delta$*', size=45)
    plt.ylabel('Accuracy (%)', fontsize=35)
    plt.tick_params(labelsize=25)
#     plt.show()
    if figname is not None:
        plt.savefig(figname)

# %%
bit_width = ['w2','w3','w4','w5','w8','w32']
kurtosis_acc_dict = {}
kurtosis_acc_dict['k = 1.8'] = [40.2,62.6,68.1,69.8,70.2,70.3]
kurtosis_acc_dict['k = 3.0'] = [20.9, 61.1, 68.2, 69.4, 70.6, 70.6]
kurtosis_acc_dict['k = 4.0'] = [7.5,58.8,66.3,69.3,70.6,70.7]
kurtosis_acc_dict['k = 6.0'] = [4.1,52.0,65.6,68.8,70.7,70.8]
kurtosis_acc_dict['Pretrained model'] = [0,44.3,61.9,65.4,69.6,69.7]

clrs=['r','y','b','g','m','k']
rcParams['figure.figsize'] = 8, 4
font = {'size': 16, 'weight': 'normal'}
matplotlib.rc('font', **font)

plt.figure()
k_list = ['k = 1.8', 'k = 3.0' ,'k = 6.0' ,'Pretrained model']
for idx, k in enumerate(k_list):
    acc_list = kurtosis_acc_dict[k]
    plt.plot(bit_width[0:], acc_list[0:],'--',marker='o',markersize=10, label=k,linewidth=3.0)

plt.xlabel('Bit-width', fontsize=16)
plt.ylabel('ResNet-18 accuracy (%)', fontsize=16)
plt.tick_params(labelsize=16)

plt.tight_layout()
figname = "../data/fig/kurtosis_val_vs_resnet18_accuracy_for_different_bit_width_for_paper_1.pdf"
if figname is not None:
    plt.savefig(figname, bbox_inches='tight')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-11-62cf38905e47> in <module>
#      46 figname = "../data/fig/kurtosis_val_vs_resnet18_accuracy_for_different_bit_width_for_paper_1.pdf"
#      47 if figname is not None:
# ---> 48     plt.savefig(figname, bbox_inches='tight')
#
# /data/moran/Robust_Quantization_With_KURE/env/lib/python3.5/site-packages/matplotlib/pyplot.py in savefig(*args, **kwargs)
#     687 def savefig(*args, **kwargs):
#     688     fig = gcf()
# --> 689     res = fig.savefig(*args, **kwargs)
#     690     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     691     return res
#
# /data/moran/Robust_Quantization_With_KURE/env/lib/python3.5/site-packages/matplotlib/figure.py in savefig(self, fname, frameon, transparent, **kwargs)
#    2092             self.set_frameon(frameon)
#    2093
# ...

# %%
# bit_width = ['w2','w3','w4','w5','w8','w32']
bit_width = ['w3','w4','w5','w6', 'w32']
kurtosis_acc_dict = {}
kurtosis_acc_dict['k = 1.6'] = [56.9,67.4,68.3,69.6,69.8,69.8]
kurtosis_acc_dict['k = 1.8'] = [40.2,62.6,68.1,69.8,70.2,70.3]
kurtosis_acc_dict['Pretrained model'] = [0,44.3,61.9,65.4,69.6,69.7]

kurtosis_acc_dict_resnet50 = {}
kurtosis_acc_dict_resnet50['k = 1.8'] = [66.5, 74.3, 75.8,76.2,76.4]
kurtosis_acc_dict_resnet50['Pretrained model'] = [38.4,70,72.9,74.8,76.1]

# clrs=['r','g','b','y','c','m','k']
clrs=['r','b','g','m','k']
# clrs=['orange','r','b','g','m']
rcParams['figure.figsize'] = 8, 6
# rcParams['figure.figsize'] = 8, 6
# rcParams['figure.figsize'] = 5, 5
# font = {'size': 16, 'weight': 'bold'}
font = {'size': 16, 'weight': 'normal'}
matplotlib.rc('font', **font)

plt.figure()
# k_list = ['k = 1.6','k = 1.8', 'k = 3.0', 'k = 4.0' ,'k = 6.0' ,'Pretrained model']
# k_list = ['k = 1.8', 'k = 3.0' ,'k = 6.0' ,'Pretrained model']
k_list = ['k = 1.8', 'Pretrained model']
for idx, k in enumerate(k_list):
    acc_list = kurtosis_acc_dict_resnet50[k]
#     plt.plot(bit_width[0:][::-1], acc_list[0:][::-1],'--', color=clrs[idx] ,marker='o',markersize=10, label=k,linewidth=3.0)
#     plt.plot(bit_width[0:][::-1], acc_list[0:][::-1],'--',marker='o',markersize=10, label=k,linewidth=3.0)
    if idx==0:
        plt.plot(bit_width[0:], acc_list[0:],marker='o', markersize=10,linewidth=3.0)
    else:
        plt.plot(bit_width[0:], acc_list[0:],marker='o',c='r', markersize=10,linewidth=3.0)
    
    

plt.legend(['PTQ with KURE','PTQ'],fontsize=16)
plt.xlabel('Bit-width', fontsize=25)
plt.ylabel('Accuracy (%)', fontsize=25)
plt.tick_params(labelsize=20)

# plt.xlabel('Bit-width', fontsize=20, fontweight='bold')
# plt.ylabel('ResNet-18 accuracy (%)', fontsize=20, fontweight='bold')
# plt.tick_params(labelsize=20)

plt.tight_layout()
figname = "../data/fig/kurtosis_val_vs_resnet18_accuracy_for_different_bit_width_for_paper_1.pdf"
if figname is not None:
    plt.savefig(figname, bbox_inches='tight')

# %%
# mobilenet-qat sensitivity

kat_acc = []
post_train_q_acc = []

bit_width = ['w3', 'w4', 'w5', 'w6', 'w8', 'w32']
bit_width_6 = ['w3a4', 'w4a4', 'w5a4', 'w6a4', 'w32a4']
dorefa_acc = [0.1, 66.814, 2.78, 1.59, 2.4, 2.48]
dorefa_bcw_acc = [2.3, 66.814, 53.42, 51.486,50.942, 50.696]
dorefa_with_kurtosis_acc = [0.5, 66.94, 41.8, 44.7, 41.5, 41.678]
dorefa_with_kurtosis_bcw_acc = [17.024, 66.94, 63.008, 63.164, 63.094, 63.294]
# lsq_acc = [44.1, 68.4, 66.3, 66.3, 66.4, 30.1]
# lsq_with_kurtosis_acc = [60.8, 68.2, 66.5, 66.8, 67.0, 67.1]

rcParams['figure.figsize'] = 8, 6
# font = {'size': 20, 'weight': 'bold'}
font = {'size': 20, 'weight': 'normal'}
matplotlib.rc('font', **font)

fig, ax = plt.subplots()
# plt.plot(kat_acc, linewidth=4, marker='o', c='g', markersize=8)
# plt.plot(dorefa_with_kurtosis_acc, linewidth=4, marker='o', markersize=8, label='Robust DoReFa')
# plt.plot(dorefa_with_kurtosis_bcw_acc, linewidth=4, marker='o', markersize=8, label='Robust DoReFa')
plt.plot(dorefa_with_kurtosis_bcw_acc, linewidth=4, marker='o', markersize=8, label='DoReFa with KURE')
# plt.plot(dorefa_acc, linewidth=4, marker='o', markersize=8, label='DoReFa')
plt.plot(dorefa_bcw_acc, linewidth=4, marker='o', c='r', markersize=8, label='DoReFa')
plt.plot([None, dorefa_bcw_acc[1],None,None, None, None, ], c='m', marker='X', markersize=15)
plt.Circle((1,1),0.7,fc='black')
# plt.plot([1,2,3], marker=matplotlib.markers.CARETDOWNBASE)

# plt.legend(['Robust Quantization', 'Robust Dorefa', 'Dorefa'], fontsize=16)
plt.legend(loc='lower center',fontsize=25)

plt.xlabel('Bit width',fontsize=25)
plt.ylabel('Accuracy (%)', fontsize=25)

ax.set_xticks(np.arange(len(bit_width)))
ax.set_xticklabels(bit_width, fontsize = 22)

plt.tight_layout()
figname = "../data/fig/qat_dorefa_sensitivity_mobilenet_v2_accu_for_different_bit_width.pdf"
if figname is not None:
    plt.savefig(figname, bbox_inches='tight')

# %%
# resnet18-qat sensitivity

kat_acc = [60.5, 66.9, 68.8, 68.9, 69.0 , 69.2]
post_train_q_acc = [48.3,61.9,65.4,67.7,68.5,68.9]

bit_width = ['w3a4', 'w4a4', 'w5a4', 'w6a4', 'w8a4', 'w32a4']
bit_width_6 = ['w3a4', 'w4a4', 'w5a4', 'w6a4', 'w32a4']
dorefa_acc = [4.8, 68.7, 59.5, 56.8, 57.172, 56.8]
dorefa_with_kurtosis_acc = [51.9, 68.5, 66.4, 65.8,66.138, 66.2]
lsq_acc = [44.1, 68.4, 66.3, 66.3, 66.4, 30.1]
lsq_with_kurtosis_acc = [60.8, 68.2, 66.5, 66.8, 67.0, 67.1]

rcParams['figure.figsize'] = 8, 6
# font = {'size': 20, 'weight': 'bold'}
font = {'size': 20, 'weight': 'normal'}
matplotlib.rc('font', **font)

fig, ax = plt.subplots()
# plt.plot(kat_acc, linewidth=4, marker='o', c='g', markersize=8)
# plt.plot(dorefa_with_kurtosis_acc, linewidth=4, marker='o', markersize=8, label='Robust DoReFa')
plt.plot(dorefa_with_kurtosis_acc, linewidth=4, marker='o', markersize=8, label='DoReFa with KURE')
# plt.plot(dorefa_acc, linewidth=4, marker='o', c='r', markersize=8, label='DoReFa')
plt.plot(dorefa_acc, linewidth=4, marker='o', c='r', markersize=8, label='DoReFa')
plt.plot([None, dorefa_acc[1],None,None, None, None, ], c='m', marker='X', markersize=15)

# plt.legend(['Robust Quantization', 'Robust Dorefa', 'Dorefa'], fontsize=16)
plt.legend(loc='lower center',fontsize=25)

plt.xlabel('Bit width',fontsize=25)
plt.ylabel('Accuracy (%)', fontsize=25)

ax.set_xticks(np.arange(len(bit_width)))
ax.set_xticklabels(bit_width, fontsize = 22)

plt.tight_layout()
figname = "../data/fig/qat_dorefa_sensitivity_resnet18_accu_for_different_bit_width.pdf"
if figname is not None:
    plt.savefig(figname, bbox_inches='tight')

# %%
rcParams['figure.figsize'] = 8, 6
# font = {'size': 20, 'weight': 'bold'}
font = {'size': 20, 'weight': 'normal'}
matplotlib.rc('font', **font)

bit_width = ['w3', 'w4', 'w5', 'w6', 'w8', 'w32']
lsq_acc = [54.768,76.874,75.286,75.376,75.490, 1.028]
lsq_with_kurtosis_acc = [70.152, 75.676,74.810,75.074,75.032, 75.024]

fig, ax = plt.subplots()
# plt.plot(kat_acc, linewidth=4, marker='o', c='g', markersize=8)
# plt.plot(lsq_with_kurtosis_acc, linewidth=4, marker='o', markersize=8, label='Robust LSQ')
plt.plot(lsq_with_kurtosis_acc, linewidth=4, marker='o', markersize=8, label='LSQ with KURE')
plt.plot(lsq_acc, linewidth=4, marker='o', c='r', markersize=8, label='LSQ')
plt.plot([None, lsq_acc[1],None,None, None, None, ], c='m', marker='X', markersize=15)

plt.legend(loc='lower center',fontsize=25)

plt.xlabel('Bit width',fontsize=25)
plt.ylabel('Accuracy (%)', fontsize=25)

ax.set_xticks(np.arange(len(bit_width)))
ax.set_xticklabels(bit_width, fontsize = 22)

plt.tight_layout()
figname = "../data/fig/qat_lsq_sensitivity_resnet50_accu_for_different_bit_width.pdf"
if figname is not None:
    plt.savefig(figname, bbox_inches='tight')

# %%
rcParams['figure.figsize'] = 8, 6
# font = {'size': 20, 'weight': 'bold'}
font = {'size': 20, 'weight': 'normal'}
matplotlib.rc('font', **font)
lsq_acc = [44.1, 68.4, 66.3, 66.3, 66.4, 30.1]
lsq_with_kurtosis_acc = [60.8, 68.2, 66.5, 66.8, 67.0, 67.1]
fig, ax = plt.subplots()
# plt.plot(kat_acc, linewidth=4, marker='o', c='g', markersize=8)
# plt.plot(lsq_with_kurtosis_acc, linewidth=4, marker='o', markersize=8, label='Robust LSQ')
plt.plot(lsq_with_kurtosis_acc, linewidth=4, marker='o', markersize=8, label='LSQ with KURE')
plt.plot(lsq_acc, linewidth=4, marker='o', c='r', markersize=8, label='LSQ')
plt.plot([None, lsq_acc[1],None,None, None, None, ], c='m', marker='X', markersize=15)

plt.legend(loc='lower center',fontsize=25)

plt.xlabel('Bit width',fontsize=25)
plt.ylabel('Accuracy (%)', fontsize=25)

ax.set_xticks(np.arange(len(bit_width)))
ax.set_xticklabels(bit_width, fontsize = 22)

plt.tight_layout()
figname = "../data/fig/qat_lsq_sensitivity_resnet18_accu_for_different_bit_width.pdf"
if figname is not None:
    plt.savefig(figname, bbox_inches='tight')

# %%
# rcParams['figure.figsize'] = 8, 6
# font = {'size': 20, 'weigh}
# matplotlib.rc('font', **font)

fig, ax = plt.subplots()
plt.plot(kat_acc, linewidth=4, marker='o', markersize=8)
plt.plot(post_train_q_acc, linewidth=4, marker='o', markersize=8)
plt.plot(lsq_with_kurtosis_acc, linewidth=4, marker='o', markersize=8)
plt.plot(lsq_acc, linewidth=4, marker='o', markersize=8)

plt.legend(['Robust Post Training Quantization','Post Training Quantiztion', 'Robust LSQ', 'LSQ'], fontsize=16)

plt.xlabel('Bit width',fontsize=25)
plt.ylabel('Accuracy (%)', fontsize=25)

ax.set_xticks(np.arange(len(bit_width)))
ax.set_xticklabels(bit_width)

plt.tight_layout()
figname = "../data/fig/qat_lsq_sensitivity_resnet18_accu_for_different_bit_width_all.png"
if figname is not None:
    plt.savefig(figname, bbox_inches='tight')

# %%
rcParams['figure.figsize'] = 8, 6
# font = {'size': 20, 'weight': 'bold'}
font = {'size': 20, 'weight': 'normal'}
matplotlib.rc('font', **font)

fig, ax = plt.subplots()
plt.plot(kat_acc , linewidth=4, marker='o', markersize=8)
plt.plot(post_train_q_acc, linewidth=4, marker='o', c='r', markersize=8)
# plt.plot(lsq_acc, linewidth=4, marker='o', c='r', markersize=8)

# plt.legend(['Robust Post Training Quantization','Post Training Quantiztion'],fontsize=16)
plt.legend(['PTQ with KURE','PTQ'],fontsize=16)

plt.xlabel('Bit width',fontsize=25)
plt.ylabel('Accuracy (%)', fontsize=25)

ax.set_xticks(np.arange(len(bit_width)))
ax.set_xticklabels(bit_width)

plt.tight_layout()
figname = "../data/fig/qat_lsq_sensitivity_resnet18_accu_for_different_bit_width.png"
if figname is not None:
    plt.savefig(figname, bbox_inches='tight')

# %%
rcParams['figure.figsize'] = 8, 6
font = {'size': 20, 'weight': 'bold'}
matplotlib.rc('font', **font)

fig, ax = plt.subplots()
plt.plot(kat_acc, linewidth=4, marker='o', c='g', markersize=8)
plt.plot(lsq_with_kurtosis_acc, linewidth=4, marker='o', markersize=8)
plt.plot(lsq_acc, linewidth=4, marker='o', c='r', markersize=8)

plt.legend(['Robust Quantization', 'Robust LSQ', 'LSQ'], fontsize=16)

plt.xlabel('Bit width',fontsize=25)
plt.ylabel('Accuracy (%)', fontsize=25)

ax.set_xticks(np.arange(len(bit_width)))
ax.set_xticklabels(bit_width)

plt.tight_layout()
figname = "../data/fig/qat_lsq_sensitivity_resnet18_accu_for_different_bit_width.png"
if figname is not None:
    plt.savefig(figname, bbox_inches='tight')

# %%
# resnet18-qat sensitivity

kat_acc = [60.5, 66.9, 68.8, 68.9, 69.0 , 69.2]


bit_width_8 = ['w3a4', 'w4a4', 'w5a4', 'w6a4', 'w8a4', 'fp32a4']
bit_width_6 = ['w3a4', 'w4a4', 'w5a4', 'w6a4', 'fp32a4']
dorefa_acc = [4.8, 68.7, 59.5, 56.8, 57.172, 56.8]
dorefa_with_kurtosis_acc = [51.9, 68.5, 66.4, 65.8,66.138, 66.2]
lsq_acc = [44.1, 68.4, 66.3, 66.3, 66.4, 30.1]
lsq_with_kurtosis_acc = [60.8, 68.2, 66.5, 66.8, 67.0, 67.1]

bar_dict = {}
for idx, val in enumerate(bit_width_8):
    bar_dict[val] = [dorefa_acc[idx], dorefa_with_kurtosis_acc[idx], kat_acc[idx]]
    
bar_dict

rcParams['figure.figsize'] = 11, 7
# plt.figure()

width = 0.15
ind = np.arange(len(bit_width_8))
plt.bar(ind + 0*width, dorefa_acc, width)
plt.bar(ind + 1*width, dorefa_with_kurtosis_acc, width)
plt.bar(ind + 2*width, kat_acc, width)

# plt.ylabel('moments change', fontsize=25)
plt.xticks(ind+width, bit_width_8);


plt.legend(['Dorefa', 'Robust Dorefa', 'Robust Quantization'], loc='upper center', bbox_to_anchor=(0.5, 1.15), ncol=4, fancybox=True, shadow=True);

figname = "../data/fig/bar_qat_dorefa_sensitivity_resnet18_accu_for_different_bit_width.png"
if figname is not None:
    plt.savefig(figname, bbox_inches='tight')


rcParams['figure.figsize'] = 11, 7
plt.figure()

width = 0.15
ind = np.arange(len(bit_width_8))
plt.bar(ind + 0*width, lsq_acc, width)
plt.bar(ind + 1*width, lsq_with_kurtosis_acc, width)
plt.bar(ind + 2*width, kat_acc, width)

# plt.ylabel('moments change', fontsize=25)
plt.xticks(ind+width, bit_width_8);


plt.legend(['LSQ', 'Robust LSQ', 'Robust Quantization'], loc='upper center', bbox_to_anchor=(0.5, 1.15), ncol=4, fancybox=True, shadow=True);

figname = "../data/fig/bar_qat_lsq_sensitivity_resnet18_accu_for_different_bit_width.png"
if figname is not None:
    plt.savefig(figname, bbox_inches='tight')

# %%
# rcParams['figure.figsize'] = 8, 6
rcParams['figure.figsize'] = 9, 8
# font = {'size': 20, 'weight': 'bold'}
font = {'size': 25, 'weight': 'normal'}
matplotlib.rc('font', **font)


lsq_orig_pkl = '/data/moran/CnnQuantization_1/nn-quantization-pytorch/res18_lsq_orig/resnet18_WALLANoneMINR0.9_MAXR1.1_GR21_BCWF.pkl' 
lsq_kurtosis_pkl = '/data/moran/CnnQuantization_1/nn-quantization-pytorch/res18_lsq_kurtosis2.2/resnet18_WALLANoneMINR0.9_MAXR1.1_GR21_BCWF.pkl'

files_list = []
files_list.append(('LSQ_w4a4',lsq_orig_pkl))
files_list.append(('Robust LSQ_w4a4',lsq_kurtosis_pkl))

# create_1D_plot(files_list, 0.5, 0.5, 1.5, 1.5, min_value=None, max_value=None)

lsq_orig_pkl = '/data/moran/CnnQuantization_1/nn-quantization-pytorch/res18_lsq_orig/resnet18_WALLANoneMINR0.7_MAXR1.3_GR21_BCWF.pkl' 
lsq_kurtosis_pkl = '/data/moran/CnnQuantization_1/nn-quantization-pytorch/res18_lsq_kurtosis2.2/resnet18_WALLANoneMINR0.7_MAXR1.3_GR21_BCWF.pkl'

files_list = []
files_list.append(('Robust LSQ_w4a4',lsq_kurtosis_pkl))
files_list.append(('LSQ_w4a4',lsq_orig_pkl))


# create_1D_plot(files_list, 0.5, 0.5, 1.5, 1.5, min_value=None, max_value=None)


files_list = []
# files_list.append(('Dorefa w4a4','/data/moran/distiller_master_0/distiller/distiller/quantization/qat_w4_2019.11.13-092130_AllWeights_ratio_scale_1D_grid_loss_acc/resnet18_WALLANoneMINR0.7_MAXR1.3_GR61_BCWFF.pkl'))
# files_list.append(('Robust Dorefa w4a4','/data/moran/distiller_master_0/distiller/distiller/quantization/qat_w4_kreg_2019.11.19-094805_AllWeights_ratio_scale_1D_grid_loss_acc/resnet18_WALLANoneMINR0.7_MAXR1.3_GR61_BCWFF.pkl'))
files_list.append(('DoReFa with KURE','/data/moran/distiller_master_0/distiller/distiller/quantization/qat_w4_kreg_2019.11.19-094805_AllWeights_ratio_scale_1D_grid_loss_acc/resnet18_WALLANoneMINR0.7_MAXR1.3_GR21.pkl'))
files_list.append(('DoReFa','/data/moran/distiller_master_0/distiller/distiller/quantization/qat_w4_2019.11.13-092130_AllWeights_ratio_scale_1D_grid_loss_acc/resnet18_WALLANoneMINR0.7_MAXR1.3_GR21.pkl'))


create_1D_plot(files_list, 0.5, 0.5, 1.5, 1.5, min_value=None, max_value=None, array_name='Z_top1', figname = "../data/fig/qat_dorefa_sensitivity_resnet18_accu_for_different_scale_ratio.pdf")
# create_1D_plot(files_list, 0.5, 0.5, 1.5, 1.5, min_value=None, max_value=None, array_name='Z_snr')

# mobilenet_v2
files_list = []
# files_list.append(('Dorefa w4a4','/data/moran/distiller_master_0/distiller/distiller/quantization/qat_w4_2019.11.13-092130_AllWeights_ratio_scale_1D_grid_loss_acc/resnet18_WALLANoneMINR0.7_MAXR1.3_GR61_BCWFF.pkl'))
# files_list.append(('Robust Dorefa w4a4','/data/moran/distiller_master_0/distiller/distiller/quantization/qat_w4_kreg_2019.11.19-094805_AllWeights_ratio_scale_1D_grid_loss_acc/resnet18_WALLANoneMINR0.7_MAXR1.3_GR61_BCWFF.pkl'))
files_list.append(('DoReFa with KURE','/data/moran/distiller_master_0/distiller/distiller/quantization/mobilenet_v2_qat_w4_2020.01.08-095140_AllWeights_ratio_scale_1D_grid_loss_acc_b/mobilenet_v2_WALLANoneMINR0.7_MAXR1.3_GR61_BCWTT.pkl'))
files_list.append(('DoReFa','/data/moran/distiller_master_0/distiller/distiller/quantization/mobilenet_v2_qat_w4_kreg_2020.01.08-095127_AllWeights_ratio_scale_1D_grid_loss_accoss_acc_b/mobilenet_v2_WALLANoneMINR0.7_MAXR1.3_GR61_BCWTT.pkl'))


create_1D_plot(files_list, 0.5, 0.5, 1.5, 1.5, min_value=None, max_value=None, array_name='Z_top1', figname = "../data/fig/qat_dorefa_sensitivity_mobilenet_v2_accu_for_different_scale_ratio.pdf")
# create_1D_plot(files_list, 0.5, 0.5, 1.5, 1.5, min_value=None, max_value=None, array_name='Z_snr')
# #################

# files_list = []
# files_list.append(('Dorefa w4a4','/data/moran/distiller_master_0/distiller/distiller/quantization/qat_w4_2019.11.13-092130_AllWeights_ratio_scale_1D_grid_loss_acc/resnet18_WALLANoneMINR0.7_MAXR1.3_GR61_BCWTT.pkl'))
# # files_list.append(('Robust Dorefa w4a4','/data/moran/distiller_master_0/distiller/distiller/quantization/qat_w4_kreg_2019.11.19-094805_AllWeights_ratio_scale_1D_grid_loss_acc/resnet18_WALLANoneMINR0.7_MAXR1.3_GR61_BCWTT.pkl'))
# # files_list.append(('Robust Dorefa w4a4','/data/moran/distiller_master_0/distiller/distiller/quantization/qat_w4_kreg_2019.11.19-094805_AllWeights_ratio_scale_1D_grid_loss_acc/resnet18_WALLANoneMINR0.9_MAXR1.1_GR41.pkl'))

# create_1D_plot(files_list, 0.5, 0.5, 1.5, 1.5, min_value=None, max_value=None, array_name='Z_bias')
# create_1D_plot(files_list, 0.5, 0.5, 1.5, 1.5, min_value=None, max_value=None, array_name='Z_snr')

# files_list = []
# files_list.append(('Dorefa w4a4 (with bias correction)','/data/moran/distiller_master_0/distiller/distiller/quantization/qat_w4_2019.11.13-092130_AllWeights_ratio_scale_1D_grid_loss_acc/resnet18_WALLANoneMINR0.7_MAXR1.3_GR61_BCWTT.pkl'))
# files_list.append(('Robust Dorefa w4a4','/data/moran/distiller_master_0/distiller/distiller/quantization/qat_w4_kreg_2019.11.19-094805_AllWeights_ratio_scale_1D_grid_loss_acc/resnet18_WALLANoneMINR0.7_MAXR1.3_GR61_BCWFF.pkl'))
# create_1D_plot(files_list, 0.5, 0.5, 1.5, 1.5, min_value=None, max_value=None, array_name='Z_top1')
# Out:
# [63.575 62.5   59.85  62.6   63.125 64.325 64.625 62.75  64.075 62.275
#  68.625 58.775 64.925 63.475 65.35  65.475 66.325 64.025 65.475 65.2
#  67.025]
# [ 3.275 11.825  1.     5.6   14.95  12.4    2.175  7.3   30.3   11.775
#  69.85   7.5   27.5   26.25  42.25  21.875 34.95  38.9   39.375 14.25
#  34.225]
# [47.54 48.92 54.02 52.26 52.14 50.5  50.92 53.82 54.64 54.38 56.   53.66
#  53.42 53.7  56.64 55.22 55.82 54.18 55.12 54.58 52.64 53.44 53.24 52.94
#  57.6  57.28 60.3  59.06 61.14 63.1  67.52 63.7  60.04 57.16 56.6  53.1
#  53.92 53.38 52.72 53.32 55.   55.58 57.62 55.06 55.18 57.78 56.84 60.1
#  58.84 60.78 57.18 57.7  57.68 58.8  61.56 57.48 59.62 57.62 58.06 58.12
#  56.36]
# [19.06 22.96 21.82 20.92 18.18 11.04 15.72 21.62 25.36 38.16 37.94 35.72
#  34.9  28.8  31.14 27.7  21.08 25.74 16.72 25.98 34.34 39.1  35.22 31.92
#  27.94 31.36 30.68 41.24 42.7  51.4  68.72 52.78 32.14 29.16 28.74 26.8
#  29.66 29.28 30.16 34.98 38.3  43.42 43.4  49.46 45.64 39.42 37.4  43.66
# ...

# %%
plt.rcParams["figure.figsize"] = 5,2

def create_heatmap_1D_3(data_path, xmin, ymin, xmax=None, ymax=None, figname=None, min_value=None, max_value=None, min_idx=None, max_idx=None):
    pkl = pickle.load(open(data_path, 'rb'))
    
    if max_idx is None:
        p_max_idx = pkl['X'].shape[0]
    else: 
        p_max_idx = max_idx
    if min_idx is None:
        p_min_idx = 0
    else:
        p_min_idx =min_idx
        
#     Z = np.array([pkl['Z'][i][i] for i in range(0,pkl['Z'].shape[0])] 
#     Z = Z[p_min_idx:p_max_idx]
    X = pkl['X'][35, p_min_idx:p_max_idx]
#     Y = pkl['Y'][int(pkl['X'].shape[0]/2), p_min_idx:p_max_idx]
    Z = pkl['Z'][35, p_min_idx:p_max_idx]
    max_point = pkl['max_point'] if 'max_point' in pkl.keys() else None
    l2_point = pkl['l2_point'] if 'l2_point' in pkl.keys() else None 
    l3_point = pkl['l3_point'] if 'l3_point' in pkl.keys() else None

    if max_value: 
        Z[Z>max_value] = max_value
    
    if min_value: 
        Z[Z<min_value] = min_value

    fig, (ax,ax2) = plt.subplots(nrows=2, sharex=True)
    extent = [X[0]-(X[1]-X[0])/2., X[-1]-(X[1]-X[0])/2.,0,1]
#     ax.imshow(Z[np.newaxis,:], cmap=cm.get_cmap("nipy_spectral"), aspect="auto", extent=extent)
    ax.imshow(Z[np.newaxis,:], cmap=cm.get_cmap("jet"), aspect="auto", extent=extent)
    ax.set_xlim(extent[0], extent[1])
    ax2.plot(X,Z)

    plt.tight_layout()
    plt.show()
#     fig, ax = plt.subplots()

#     c = ax.pcolormesh(X, Y, Z, cmap=cm.get_cmap("nipy_spectral"))
# #     cbar = fig.colorbar(c, ax=ax, orientation='horizontal')
#     cbar = fig.colorbar(c, ax=ax)
#     cbar.ax.tick_params(labelsize=12) 

#     plt.tight_layout()
#     plt.tick_params(labelsize=12)
#     if figname is not None:
#         plt.savefig(figname)

create_heatmap_1D_3('../data/m_w4_loss_surface_resnet18_pretrained_ratio_scale_grid_minr0.1_maxr1.5/resnet18_l0l1_W4ANone.pkl', 0.1, 0.1, 1.5, 1.5, min_value=1.55, max_value=1.8, max_idx=62, figname='../data/fig/heatmap_pretrained_layers01.png')
create_heatmap_1D_3('../data/m_w4_loss_surface_resnet18_k1.8_2019.12.06-232047_ratio_scale_grid_minr0.1_maxr1.5/resnet18_l0l1_W4ANone.pkl', 0.1, 0.1, 1.5, 1.5, min_value=1.55, max_value=1.8, max_idx=62, figname='../data/fig/heatmap_kurtosis_layers01.png')
create_heatmap_1D_3('../data/m_w4_loss_surface_resnet18_pretrained_ratio_scale_grid_minr0.1_maxr1.5/resnet18_l4l5_W4ANone.pkl', 0.1, 0.1, 1.5, 1.5, min_value=1.55, max_value=1.8, figname='../data/fig/heatmap_pretrained_layers45.png')
create_heatmap_1D_3('../data/m_w4_loss_surface_resnet18_k1.8_2019.12.06-232047_ratio_scale_grid_minr0.1_maxr1.5/resnet18_l4l5_W4ANone.pkl', 0.1, 0.1, 1.5, 1.5, min_value=1.55, max_value=1.8, figname='../data/fig/heatmap_kurtosis_layers45.png')

# %%
from mpl_toolkits import mplot3d
def create_heatmap_surface_4(data_path, xmin, ymin, xmax=None, ymax=None, figname=None, min_value=None, max_value=None, min_idx=None, max_idx=None):
    pkl = pickle.load(open(data_path, 'rb'))
    
    if max_idx is None:
        p_max_idx = pkl['X'].shape[0]
    else: 
        p_max_idx = max_idx
    if min_idx is None:
        p_min_idx = 0
    else:
        p_min_idx =min_idx
    X = pkl['X'][p_min_idx:p_max_idx, p_min_idx:p_max_idx]
    Y = pkl['Y'][p_min_idx:p_max_idx, p_min_idx:p_max_idx]
    Z = pkl['Z'][p_min_idx:p_max_idx, p_min_idx:p_max_idx]
    
    max_point = pkl['max_point'] if 'max_point' in pkl.keys() else None
    l2_point = pkl['l2_point'] if 'l2_point' in pkl.keys() else None 
    l3_point = pkl['l3_point'] if 'l3_point' in pkl.keys() else None
#     laplace_point = pkl['laplace_point']



    if max_value: 
        Z[Z>max_value] = max_value
    
    if min_value: 
        Z[Z<min_value] = min_value

    fig = plt.figure(figsize=(5, 5))
    ax = plt.axes(projection='3d')
    ax.view_init(30, 90)
    # ax.contour3D(X, Y, Z, 100, cmap=cm.CMRmap)
    ax.plot_surface(X, Y, Z, cmap=cm.jet)
    ax.set_xlabel('x')
    ax.set_ylabel('y')
    ax.set_zlabel('z');
    plt.tight_layout()
    plt.tick_params(labelsize=12)
    
    # rotate the axes and update
#     for angle in range(0, 360):
#         ax.view_init(30, angle)
#         plt.draw()
#         plt.pause(.001)
#     if figname is not None:
#     plt.savefig(figname)
        

# ax.view_init(45, -135)

# create_heatmap_surface_4('../data/m_w4_loss_surface_resnet18_pretrained_ratio_scale_grid_minr0.1_maxr1.5/resnet18_l0l1_W4ANone.pkl', 0.1, 0.1, 1.5, 1.5, min_value=1.5, max_value=4, max_idx=62, figname='../data/fig/heatmap_pretrained_layers01.png')
# create_heatmap_surface_4('../data/m_w4_loss_surface_resnet18_k1.8_2019.12.06-232047_ratio_scale_grid_minr0.1_maxr1.5/resnet18_l0l1_W4ANone.pkl', 0.1, 0.1, 1.5, 1.5, min_value=1.5, max_value=4, max_idx=62, figname='../data/fig/heatmap_kurtosis_layers01.png')

# %%
rcParams['figure.figsize'] = 8, 6
create_heatmap_2('../data/m_w4_loss_surface_resnet18_pretrained_ratio_scale_grid_minr0.1_maxr1.5/resnet18_l0l1_W4ANone.pkl', 0.1, 0.1, 1.5, 1.5, min_value=1.55, max_value=6, max_idx=62, figname='../data/fig/heatmap_pretrained_layers01.pdf')
create_heatmap_2('../data/m_w4_loss_surface_resnet18_pretrained_ratio_scale_grid_minr0.1_maxr1.5/resnet18_l4l5_W4ANone.pkl', 0.1, 0.1, 1.5, 1.5, min_value=1.55, max_value=6, figname='../data/fig/heatmap_pretrained_layers45.pdf')
create_heatmap_2('../data/m_w4_loss_surface_resnet18_k1.8_2019.12.06-232047_ratio_scale_grid_minr0.1_maxr1.5/resnet18_l0l1_W4ANone.pkl', 0.1, 0.1, 1.5, 1.5, min_value=1.55, max_value=6, max_idx=62, figname='../data/fig/heatmap_kurtosis_layers01.pdf')
create_heatmap_2('../data/m_w4_loss_surface_resnet18_k1.8_2019.12.06-232047_ratio_scale_grid_minr0.1_maxr1.5/resnet18_l4l5_W4ANone.pkl', 0.1, 0.1, 1.5, 1.5, min_value=1.55, max_value=6, figname='../data/fig/heatmap_kurtosis_layers45.pdf')

# %%
# resnet18-qat sensitivity




bit_width = ['w3a3','w3a4', 'w4a4', 'w5a4','w5a5', 'w6a4','w6a6', 'w8a4','w8a8', 'fp32a4''wfp32afp32',]
pretrained_acc = [4.8, 68.7, 59.5, 56.8, 57.172, 56.8]
kat_acc = [51.9, 68.5, 66.4, 65.8,66.138, 66.2]

rcParams['figure.figsize'] = 11, 7
plt.figure()
plt.plot(bit_width, dorefa_acc, color='b' ,marker='o', label='Pretrained')
plt.plot(bit_width, dorefa_with_kurtosis_acc, color='r',marker='o', label='KAT')
# plt.plot(bit_width_8, kat_acc, color='g',marker='o', label='KAT')
plt.legend(loc='lower center', fontsize=18)
plt.xlabel('bit width', fontsize=18)
plt.ylabel('resnet18 accuracy', fontsize=18)
plt.tick_params(labelsize=20)
# plt.title(name)
# plt.axes
# plt.show()
figname = "../data/fig/PostTrainQ_pretrained_vs_kurtosis.png"
if figname is not None:
    plt.savefig(figname, bbox_inches='tight')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-43-b22b726fadee> in <module>
#      10 rcParams['figure.figsize'] = 11, 7
#      11 plt.figure()
# ---> 12 plt.plot(bit_width, dorefa_acc, color='b' ,marker='o', label='Pretrained')
#      13 plt.plot(bit_width, dorefa_with_kurtosis_acc, color='r',marker='o', label='KAT')
#      14 # plt.plot(bit_width_8, kat_acc, color='g',marker='o', label='KAT')
#
# NameError: name 'dorefa_acc' is not defined

# %%
rcParams['figure.figsize'] = 8, 8
# create_heatmap('../data/resnet18_l0l1_WNoneA2.pkl', 0.1, 0.1, '../fig/resnet18_l0l1_WNoneA2.png')
create_heatmap(data_files[0], 0.1, 0.1, min_value=1.526, max_value=3)

# %%
rcParams['figure.figsize'] = 8, 8
# create_heatmap('../data/resnet18_l0l1_WNoneA3.pkl', 0.1, 0.1, '../fig/resnet18_l0l1_WNoneA3.png')
create_heatmap(data_files[1], 0.01, 0.01, min_value=1.526, max_value=3)

# %%
rcParams['figure.figsize'] = 8, 8
# create_heatmap('../data/resnet18_l0l1_WNoneA2.pkl', 0.1, 0.1, '../fig/resnet18_l0l1_WNoneA2.png')
create_heatmap(data_files[3], 0.01, 0.01)
# Out:
# /data/moran/CnnQuantization_1/nn-quantization-pytorch/env/lib/python3.5/site-packages/scipy/interpolate/_fitpack_impl.py:976: RuntimeWarning: No more knots can be added because the number of B-spline
# coefficients already exceeds the number of data points m.
# Probable causes: either s or m too small. (fp>s)
# 	kx,ky=1,1 nx,ny=51,54 m=2500 fp=0.080914 s=0.000000
#   warnings.warn(RuntimeWarning(_iermess2[ierm][0] + _mess))

# %%
rcParams['figure.figsize'] = 8, 8
# create_heatmap('../data/m_w4_loss_surface_2019.11.19-150720_epoch_90_high_res_fixed_grid/resnet18_l0l1_W4ANone.pkl', 0.063, 0.053)

# loss 0-7
# create_heatmap('../data/m_w4_loss_surface_2019.11.19-150720_epoch_90_high_res_doubled_grid/resnet18_l0l1_W4ANone.pkl', 0.068, 0.053, 0.25,0.25)

# whole grid
# create_heatmap('../data/m_w4_loss_surface_2019.11.19-150720_epoch_90_high_res_doubled_grid/resnet18_l0l1_W4ANone.pkl', 0.07, 0.065, 0.28,0.24, min_value=1.0, max_value=6.0)
# create_heatmap('../data/m_w4_loss_surface_2019.11.19-150720_epoch_90_high_res_doubled_grid/resnet18_l0l1_W4ANone.pkl', 0.01, 0.01, 0.5,0.5, max_value=5)
# 
# scales ratio 
# create_heatmap('../data/m_w4_loss_surface_2019.11.19-150720_epoch_90_ratio_scale_grid/resnet18_l0l1_W4ANone.pkl', 0.5, 0.5, 1.5, 1.5, max_value=5)
create_heatmap('../data/m_w4_loss_surface_2019.11.19-150720_epoch_90_ratio_scale_grid_minr0.1_maxr1.5/resnet18_l0l1_W4ANone.pkl', 0.1, 0.1, 1.5, 1.5, min_value=1.5, max_value=10)


# create_heatmap('../data/m_w4_loss_surface_2019.11.19-150720_epoch_90_high_res_fixed_grid/resnet18_l0l1_W4ANone.pkl', 0.063, 0.063,0.45,0.35)
# create_heatmap(data_files[3], 0.01, 0.01, 0.2, 0.2 )
# Out:
# /data/moran/CnnQuantization_1/nn-quantization-pytorch/env/lib/python3.5/site-packages/scipy/interpolate/_fitpack_impl.py:976: RuntimeWarning: No more knots can be added because the number of B-spline
# coefficients already exceeds the number of data points m.
# Probable causes: either s or m too small. (fp>s)
# 	kx,ky=1,1 nx,ny=53,52 m=2500 fp=0.000000 s=0.000000
#   warnings.warn(RuntimeWarning(_iermess2[ierm][0] + _mess))

# %%
rcParams['figure.figsize'] = 8, 8
# create_heatmap('../data/m_w4_loss_surface_pretrained_high_res_fixed_grid/resnet18_l0l1_W4ANone.pkl', 0.1, 0.1,None,0.5)

# loss 0-7
# create_heatmap('../data/m_w4_loss_surface_pretrained_high_res_doubled_grid/resnet18_l0l1_W4ANone.pkl', 0.1, 0.1, 1.0, 0.8)

# create_heatmap('../data/m_w4_loss_surface_pretrained_high_res_doubled_grid/resnet18_l0l1_W4ANone.pkl', 0.4, 0.25, 1.6, 1.0, min_value=1.5, max_value=6)

# scale ratio
# create_heatmap('../data/m_w4_loss_surface_pretrained_ratio_scale_grid/resnet18_l0l1_W4ANone.pkl', 0.5, 0.5, 1.5, 1.5, max_value=5)
create_heatmap('../data/m_w4_loss_surface_pretrained_ratio_scale_grid_minr0.1_maxr1.5/resnet18_l0l1_W4ANone.pkl', 0.1, 0.1, 1.5, 1.5, max_value=10)

# pkl = pickle.load(open('../data/m_w4_loss_surface_pretrained_ratio_scale_grid_minr0.1_maxr1.5/resnet18_l0l1_W4ANone.pkl', 'rb'))
# #     X = pkl['X']
# #     Y = pkl['Y']
# #     Z = pkl['Z']
# max_point = pkl['max_point']
# l2_point = pkl['l2_point']
# l3_point = pkl['l3_point']

# l2_point
# l3_point
# whole grid
# create_heatmap('../data/m_w4_loss_surface_pretrained_high_res_doubled_grid/resnet18_l0l1_W4ANone.pkl', 0.01, 0.01, 1.6, 1.0, max_value=5)

# %%
# rcParams['figure.figsize'] = 8, 8
# create_heatmap('../data/temp/resnet18_l4l5_W4ANone.pkl', 0.01, 0.01,0.5,0.5)
# create_heatmap('../data/temp/resnet18_l4l5_W4ANone.pkl', 0.01, 0.01, 0.5, 0.5, min_value=1.5, max_value=4)

create_heatmap('../data/m_w4_loss_surface_resnet18_pretrained_ratio_scale_grid_minr0.1_maxr1.5/resnet18_l4l5_W2ANone.pkl', 0.1, 0.1, 1.5, 1.5, min_value=2.5, max_value=8)
create_heatmap('../data/m_w4_loss_surface_resnet18_k3.0_2019.12.11-150717_ratio_scale_grid_minr0.1_maxr1.5/resnet18_l4l5_W2ANone.pkl', 0.1, 0.1, 1.5, 1.5, min_value=2.5, max_value=8)
# create_heatmap('../data/m_w4_loss_surface_resnet18_k1.8_2019.12.06-232047_ratio_scale_grid_minr0.1_maxr1.5/resnet18_l4l5_W2ANone.pkl', 0.1, 0.1, 1.5, 1.5, min_value=2.5, max_value=8)

create_heatmap('../data/m_w4_loss_surface_resnet18_pretrained_ratio_scale_grid_minr0.1_maxr1.5/resnet18_l4l5_W3ANone.pkl', 0.1, 0.1, 1.5, 1.5, min_value=1.7, max_value=8)
create_heatmap('../data/m_w4_loss_surface_resnet18_k3.0_2019.12.11-150717_ratio_scale_grid_minr0.1_maxr1.5/resnet18_l4l5_W3ANone.pkl', 0.1, 0.1, min_value=1.7, max_value=8)
# create_heatmap('../data/m_w4_loss_surface_resnet18_k1.8_2019.12.06-232047_ratio_scale_grid_minr0.1_maxr1.5/resnet18_l4l5_W3ANone.pkl', 0.1, 0.1, 1.5, 1.5, min_value=1.7, max_value=8)

create_heatmap('../data/m_w4_loss_surface_resnet18_pretrained_ratio_scale_grid_minr0.1_maxr1.5/resnet18_l0l1_W4ANone.pkl', 0.1, 0.1, min_value=1.5, max_value=8)
create_heatmap('../data/m_w4_loss_surface_resnet18_pretrained_ratio_scale_grid_minr0.1_maxr1.5/resnet18_l4l5_W4ANone.pkl', 0.1, 0.1, min_value=1.5, max_value=8)
# create_heatmap('../data/m_w4_loss_surface_2019.11.19-150720_epoch_90_ratio_scale_grid_minr0.1_maxr1.5/resnet18_l0l1_W4ANone.pkl', 0.1, 0.1, min_value=1.0, max_value=5)
# create_heatmap('../data/m_w4_loss_surface_2019.12.05-093202_epoch_best_ratio_scale_grid_minr0.1_maxr1.5/resnet18_l4l5_W4ANone.pkl', 0.1, 0.1, min_value=1.0, max_value=5)
# create_heatmap('../data/m_w4_loss_surface_2019.12.05-093202_epoch_0_ratio_scale_grid_minr0.1_maxr1.5/resnet18_l4l5_W4ANone.pkl', 0.1, 0.1, min_value=1.0, max_value=5)
create_heatmap('../data/m_w4_loss_surface_resnet18_k1.8_2019.12.06-232047_ratio_scale_grid_minr0.1_maxr1.5/resnet18_l0l1_W4ANone.pkl', 0.1, 0.1, 1.5, 1.5, min_value=1.5, max_value=8)
create_heatmap('../data/m_w4_loss_surface_resnet18_k1.8_2019.12.06-232047_ratio_scale_grid_minr0.1_maxr1.5/resnet18_l4l5_W4ANone.pkl', 0.1, 0.1, 1.5, 1.5, min_value=1.5, max_value=8)




# create_heatmap('../data/temp/resnet18_l4l5_W4ANone.pkl', 0.33*0.5, 0.43*0.5, 0.5, 0.5, min_value=1.0, max_value=4)
# Out:
# /data/moran/CnnQuantization_1/nn-quantization-pytorch/env/lib/python3.5/site-packages/scipy/interpolate/_fitpack_impl.py:976: RuntimeWarning: No more knots can be added because the number of B-spline
# coefficients already exceeds the number of data points m.
# Probable causes: either s or m too small. (fp>s)
# 	kx,ky=1,1 nx,ny=84,83 m=6561 fp=0.018152 s=0.000000
#   warnings.warn(RuntimeWarning(_iermess2[ierm][0] + _mess))
# /data/moran/CnnQuantization_1/nn-quantization-pytorch/env/lib/python3.5/site-packages/scipy/interpolate/_fitpack_impl.py:976: RuntimeWarning: No more knots can be added because the number of B-spline
# coefficients already exceeds the number of data points m.
# Probable causes: either s or m too small. (fp>s)
# 	kx,ky=1,1 nx,ny=81,86 m=6561 fp=0.386426 s=0.000000
#   warnings.warn(RuntimeWarning(_iermess2[ierm][0] + _mess))
# ...

# %%
rcParams['figure.figsize'] = 8, 8
# create_heatmap('../data/resnet18_l0l1_WNoneA3.pkl', 0.1, 0.1, '../fig/resnet18_l0l1_WNoneA3.png')
# create_heatmap_only('/data/moran/distiller_master_0/distiller/distiller/quantization/qat_w4_2019.11.13-092130_ratio_scale_grid/resnet18_l0l1_W4ANone.pkl', 0.5, 0.5, 1.5, 1.5, min_value=1.0, max_value=None, intr=True)

files_list = []
files_list.append(('qat_w4','/data/moran/distiller_master_0/distiller/distiller/quantization/qat_w4_2019.11.13-092130_AllWeights_ratio_scale_1D_grid/resnet18_WALLANone.pkl'))
# files_list.append(('qat_w4_bcw','/data/moran/distiller_master_0/distiller/distiller/quantization/qat_w4_2019.11.13-092130_bcw_AllWeights_ratio_scale_1D_grid/resnet18_WALLANone.pkl'))
files_list.append(('qat_with_kurtosis_loss_w4','/data/moran/distiller_master_0/distiller/distiller/quantization/qat_w4_kreg_2019.11.19-094805_AllWeights_ratio_scale_1D_grid/resnet18_WALLANone.pkl'))
# files_list.append(('qat_with_kurtosis_loss_w4_bcw','/data/moran/distiller_master_0/distiller/distiller/quantization/qat_w4_kreg_2019.11.19-094805_bcw_AllWeights_ratio_scale_1D_grid/resnet18_WALLANone.pkl'))

create_1D_plot(files_list, 0.5, 0.5, 1.5, 1.5, min_value=None, max_value=None)

# create_1D_plot('/data/moran/distiller_master_0/distiller/distiller/quantization/qat_w4_2019.11.13-092130_AllWeights_ratio_scale_1D_grid/resnet18_WALLANone.pkl', 0.5, 0.5, 1.5, 1.5, min_value=1.0, max_value=None)
# create_1D_plot('/data/moran/distiller_master_0/distiller/distiller/quantization/qat_w4_2019.11.13-092130_bcw_AllWeights_ratio_scale_1D_grid/resnet18_WALLANone.pkl', 0.5, 0.5, 1.5, 1.5, min_value=1.0, max_value=None)
# create_1D_plot('/data/moran/distiller_master_0/distiller/distiller/quantization/qat_w4_kreg_2019.11.19-094805_AllWeights_ratio_scale_1D_grid/resnet18_WALLANone.pkl', 0.5, 0.5, 1.5, 1.5, min_value=1.0, max_value=None)
# create_1D_plot('/data/moran/distiller_master_0/distiller/distiller/quantization/qat_w4_kreg_2019.11.19-094805_bcw_AllWeights_ratio_scale_1D_grid/resnet18_WALLANone.pkl', 0.5, 0.5, 1.5, 1.5, min_value=1.0, max_value=None)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-14-d7dbaf14a40b> in <module>
#       9 # files_list.append(('qat_with_kurtosis_loss_w4_bcw','/data/moran/distiller_master_0/distiller/distiller/quantization/qat_w4_kreg_2019.11.19-094805_bcw_AllWeights_ratio_scale_1D_grid/resnet18_WALLANone.pkl'))
#      10
# ---> 11 create_1D_plot(files_list, 0.5, 0.5, 1.5, 1.5, min_value=None, max_value=None)
#      12
#      13 # create_1D_plot('/data/moran/distiller_master_0/distiller/distiller/quantization/qat_w4_2019.11.13-092130_AllWeights_ratio_scale_1D_grid/resnet18_WALLANone.pkl', 0.5, 0.5, 1.5, 1.5, min_value=1.0, max_value=None)
#
# <ipython-input-12-c55d50417012> in create_1D_plot(files_list, xmin, ymin, xmax, ymax, figname, min_value, max_value)
#      12         X = pkl['X']
#      13 #         Z = pkl['Z_loss']
# ---> 14         Z = pkl['Z_top1']
# ...

# %%
rcParams['figure.figsize'] = 8, 8

files_list = []


# files_list.append(('Dorefa w4a4','/data/moran/distiller_master_0/distiller/distiller/quantization/qat_w4_2019.11.13-092130_AllWeights_ratio_scale_1D_grid_loss_acc/resnet18_WALLANoneMINR0.9_MAXR1.1_GR41.pkl'))
# files_list.append(('Dorefa with kurtosis = 1.8, w4a4','/data/moran/distiller_master_0/distiller/distiller/quantization/qat_w4_kreg_2019.11.19-094805_AllWeights_ratio_scale_1D_grid_loss_acc/resnet18_WALLANoneMINR0.9_MAXR1.1_GR41.pkl'))

files_list.append(('Dorefa w4a4','/data/moran/distiller_master_0/distiller/distiller/quantization/qat_w4_2019.11.13-092130_bcw_AllWeights_ratio_scale_1D_grid/resnet18_WALLANoneMINR0.9_MAXR1.1_GR41_BCWT.pkl'))
create_1D_plot(files_list, 0.5, 0.5, 1.5, 1.5, min_value=None, max_value=None)

# %%
rcParams['figure.figsize'] = 8, 8
# create_heatmap('../data/resnet18_l0l1_WNoneA3.pkl', 0.1, 0.1, '../fig/resnet18_l0l1_WNoneA3.png')
create_heatmap(data_files[1], 0.01, 0.01)

# %%
rcParams['figure.figsize'] = 8, 8
min_value = 1.25
max_value = 1.35
create_heatmap_only("QAT W4 layers [0,1]" , '/data/moran/distiller_master_0/distiller/distiller/quantization/qat_w4_2019.11.13-092130_ratio_scale_grid/resnet18_l0l1_W4ANone.pkl', 0.7, 0.7, 1.3, 1.3, min_value=min_value, max_value=max_value)
create_heatmap_only("QAT W4 layers [0,1] BCW" , '/data/moran/distiller_master_0/distiller/distiller/quantization/qat_w4_2019.11.13-092130_bcw_ratio_scale_grid/resnet18_l0l1_W4ANone.pkl', 0.7, 0.7, 1.3, 1.3, min_value=min_value, max_value=max_value)
create_heatmap_only("QAT w/ Kurtosis W4 layers [0,1]" , '/data/moran/distiller_master_0/distiller/distiller/quantization/qat_kreg_2019.11.19-094805_ratio_scale_grid/resnet18_l0l1_W4ANone.pkl', 0.7, 0.7, 1.3, 1.3, min_value=min_value, max_value=max_value)
create_heatmap_only("QAT w/ Kurtosis W4 layers [0,1] BCW" , '/data/moran/distiller_master_0/distiller/distiller/quantization/qat_kreg_2019.11.19-094805_bcw_ratio_scale_grid/resnet18_l0l1_W4ANone.pkl', 0.7, 0.7, 1.3, 1.3, min_value=min_value, max_value=max_value)
create_heatmap_only("QAT W4 layers [4,5]" , '/data/moran/distiller_master_0/distiller/distiller/quantization/qat_w4_2019.11.13-092130_ratio_scale_grid/resnet18_l4l5_W4ANone.pkl', 0.7, 0.7, 1.3, 1.3, min_value=min_value, max_value=max_value)
create_heatmap_only("QAT W4 layers [4,5] BCW", '/data/moran/distiller_master_0/distiller/distiller/quantization/qat_w4_2019.11.13-092130_bcw_ratio_scale_grid/resnet18_l4l5_W4ANone.pkl', 0.7, 0.7, 1.3, 1.3, min_value=min_value, max_value=max_value)
create_heatmap_only("QAT w/ Kurtosis W4 layers [4,5]" , '/data/moran/distiller_master_0/distiller/distiller/quantization/qat_kreg_2019.11.19-094805_ratio_scale_grid/resnet18_l4l5_W4ANone.pkl', 0.7, 0.7, 1.3, 1.3, min_value=min_value, max_value=max_value)
create_heatmap_only("QAT w/ Kurtosis W4 layers [4,5] BCW" , '/data/moran/distiller_master_0/distiller/distiller/quantization/qat_kreg_2019.11.19-094805_bcw_ratio_scale_grid/resnet18_l4l5_W4ANone.pkl', 0.7, 0.7, 1.3, 1.3, min_value=min_value, max_value=max_value)

# %%
rcParams['figure.figsize'] = 8, 8
create_heatmap('../data/resnet18_l0l1_WNoneA5.pkl', 0.1, 0.1, '../fig/resnet18_l0l1_WNoneA5.png')

# %%
rcParams['figure.figsize'] = 8, 8
create_heatmap('../data/resnet18_l0l1_WNoneA6.pkl', 0.1, 0.1, '../fig/resnet18_l0l1_WNoneA6.png')

# %%
rcParams['figure.figsize'] = 8, 8
create_heatmap('../data/resnet18_l0l1_WNoneA7.pkl', 0.1, 0.1, '../fig/resnet18_l0l1_WNoneA7.png')

# %%
rcParams['figure.figsize'] = 8, 8
create_heatmap('../data/resnet18_l0l1_WNoneA8.pkl', 0.1, 0.1, '../fig/resnet18_l0l1_WNoneA8.png')
